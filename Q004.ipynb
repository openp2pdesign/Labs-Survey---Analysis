# %% [markdown]
# # Q004 - Dove si trova il laboratorio?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/lab-survey.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# Get the distribution of cities
data["D4[SQ001]"] = data["D4[SQ001]"].str.lower()
city = data["D4[SQ001]"].value_counts(dropna=False)
print "Data:"
print city
print ""
print "Data %:"
print data["D4[SQ001]"].value_counts(normalize=True,dropna=False) * 100

# Plot the data
plt.figure(figsize=(16,6))
plt.xlabel(u'Cittá', fontsize=16)
plt.ylabel('Lab', fontsize=16)
plt.title(u"Dove si trova il laboratorio?", fontsize=18, y=1.02)
my_colors = seaborn.color_palette("husl", len(city)) # Set color palette
city.plot(kind="bar",color=my_colors)
plt.savefig(u"svg/Q004-CittáLab.svg")
plt.savefig(u"png/Q004-CittáLab.png")
plt.savefig(u"pdf/Q004-CittáLab.pdf")
# Out:
# Data:
# milano                 7
# roma                   5
# terni                  2
# firenze                2
# pesaro                 1
# nuoro                  1
# cesena + rimini        1
# aosta                  1
# pavia                  1
# reggio emilia          1
# trieste                1
# alessandria            1
# cascina (pi)           1
# torino                 1
# ivrea                  1
# rimini                 1
# comunanza (ap)         1
# uggiano la chiesa      1
# roma                   1
# rho                    1
# trento                 1
# genova                 1
# cinquefrondi rc        1
# borgomanero            1
# bagnacavallo (ra)      1
# parma                  1
# maniago (pn)           1
# chieri                 1
# sesto fiorentino       1
# alpignano (to)         1
# fabriano               1
# messina                1
# imperia                1
# isernia                1
# tolentino              1
# venezia                1
# bucine                 1
# settimo torinese       1
# san dona di piave      1
# bolzano                1
# cenadi                 1
# palermo                1
# torino                 1
# padova                 1
# frosinone              1
# pula                   1
# faenza                 1
# grassano               1
# treviso                1
# catania                1
# bologna                1
# tavagnacco             1
# cavriglia              1
# casalecchio di reno    1
# verona                 1
# tradate                1
# sesto san giovanni     1
# NaN                    0
# Length: 58, dtype: int64
#
# Data %:
# milano                 10.144928
# roma                    7.246377
# terni                   2.898551
# firenze                 2.898551
# pesaro                  1.449275
# nuoro                   1.449275
# cesena + rimini         1.449275
# aosta                   1.449275
# pavia                   1.449275
# reggio emilia           1.449275
# trieste                 1.449275
# alessandria             1.449275
# cascina (pi)            1.449275
# torino                  1.449275
# ivrea                   1.449275
# rimini                  1.449275
# comunanza (ap)          1.449275
# uggiano la chiesa       1.449275
# roma                    1.449275
# rho                     1.449275
# trento                  1.449275
# genova                  1.449275
# cinquefrondi rc         1.449275
# borgomanero             1.449275
# bagnacavallo (ra)       1.449275
# parma                   1.449275
# maniago (pn)            1.449275
# chieri                  1.449275
# sesto fiorentino        1.449275
# alpignano (to)          1.449275
# fabriano                1.449275
# messina                 1.449275
# imperia                 1.449275
# isernia                 1.449275
# tolentino               1.449275
# venezia                 1.449275
# bucine                  1.449275
# settimo torinese        1.449275
# san dona di piave       1.449275
# bolzano                 1.449275
# cenadi                  1.449275
# palermo                 1.449275
# torino                  1.449275
# padova                  1.449275
# frosinone               1.449275
# pula                    1.449275
# faenza                  1.449275
# grassano                1.449275
# treviso                 1.449275
# catania                 1.449275
# bologna                 1.449275
# tavagnacco              1.449275
# cavriglia               1.449275
# casalecchio di reno     1.449275
# verona                  1.449275
# tradate                 1.449275
# sesto san giovanni      1.449275
# NaN                     0.000000
# Length: 58, dtype: float64
