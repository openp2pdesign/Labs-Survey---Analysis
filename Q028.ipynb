# %% [markdown]
# # Q028 - Quali sono le dotazioni di macchinari di fabbricazione digitale del laboratorio?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/lab-survey.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# For each subquestion, plot the data
subquestions = ["D28[SQ001]","D28[SQ002]","D28[SQ003]",
                "D28[SQ004]","D28[SQ005]","D28[SQ006]",
                "D28[SQ007]","D28[SQ008]","D28[SQ009]",
                "D28[SQ010]","D28[SQ011]","D28[SQ012]",
                "D28[SQ013]","D28[SQ016]","D28[SQ014]",
                "D28[SQ015]"]
subquestions_value = [u"Fresatrice CNC di piccole dimensioni (indicativamente fino a 40cm)",
                      u"Fresatrice CNC di medie dimensioni (indicativamente fino a 1,50m)",
                      u"Fresatrice CNC di grandi dimensioni (indicativamente oltre 1,50m)",
                      u"Tornio CNC",
                      u"Taglio laser fino a 40 W di potenza",
                      u"Taglio laser oltre i 40 W di potenza",
                      u"Taglio vinile CNC",
                      u"Taglio al plasma",
                      u"Taglio a getto d’acqua",
                      u"Stampanti 3D: tecnologia FDM",
                      u"Stampanti 3D: stereolitografia (SLA, DLP)",
                      u"Stampanti 3D: a polvere",
                      u"Micro-controller (Arduino, Raspberry PI,..)",
                      u"Postazione di lavorazione elettronica (oscilloscopio, saldatore, ecc.)",
                      u"Macchina da taglio e cucito digitale",
                      u"Macchina da ricamo digitale"]

for k,i in enumerate(subquestions):
    space = data[i].value_counts(dropna=False)
    print "Data:",subquestions_value[k]
    print space
    print ""
    print "Data %:"
    print data[i].value_counts(normalize=True, dropna=False) * 100
    print ""
    print "Data: statistics:"
    print data[i].describe()

    # Plot the data 01
    plt.figure(figsize=(8,6))
    plt.xlabel(subquestions_value[k], fontsize=16)
    plt.ylabel('Lab', fontsize=16)
    plt.title(u"Quali sono le dotazioni di macchinari di fabbricazione digitale del laboratorio? "+subquestions_value[k], fontsize=18)
    my_colors = seaborn.color_palette("husl", len(space)) # Set color palette
    space.plot(kind="bar",color=my_colors)
    plt.savefig(u"svg/Q028-"+subquestions_value[k]+"01.svg")
    plt.savefig(u"png/Q028-"+subquestions_value[k]+"01.png")
# Out:
# Data: Fresatrice CNC di piccole dimensioni (indicativamente fino a 40cm)
# NaN    37
#  1     27
#  3      2
#  2      2
#  0      2
# dtype: int64
#
# Data %:
# NaN    52.857143
#  1     38.571429
#  3      2.857143
#  2      2.857143
#  0      2.857143
# dtype: float64
#
# Data: statistics:
# count    33.000000
# mean      1.121212
# std       0.599874
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: D28[SQ001], dtype: float64
# Data:
#  Fresatrice CNC di medie dimensioni (indicativamente fino a 1,50m)
# NaN    51
#  1     12
#  0      6
#  2      1
# dtype: int64
#
# Data %:
# NaN    72.857143
#  1     17.142857
#  0      8.571429
#  2      1.428571
# dtype: float64
#
# Data: statistics:
# count    19.000000
# mean      0.736842
# std       0.561951
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: D28[SQ002], dtype: float64
# Data:
#  Fresatrice CNC di grandi dimensioni (indicativamente oltre 1,50m)
# NaN    56
#  1      7
#  0      7
# dtype: int64
#
# Data %:
# NaN    80
#  1     10
#  0     10
# dtype: float64
#
# Data: statistics:
# count    14.000000
# mean      0.500000
# std       0.518875
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000
# Name: D28[SQ003], dtype: float64
# Data:
#  Tornio CNC
# NaN    61
#  0      6
#  1      2
#  3      1
# dtype: int64
#
# Data %:
# NaN    87.142857
#  0      8.571429
#  1      2.857143
#  3      1.428571
# dtype: float64
#
# Data: statistics:
# count    9.000000
# mean     0.555556
# std      1.013794
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000
# Name: D28[SQ004], dtype: float64
# Data:
#  Taglio laser fino a 40 W di potenza
# NaN    57
#  1      7
#  0      6
# dtype: int64
#
# Data %:
# NaN    81.428571
#  1     10.000000
#  0      8.571429
# dtype: float64
#
# Data: statistics:
# count    13.000000
# mean      0.538462
# std       0.518875
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: D28[SQ005], dtype: float64
# Data:
#  Taglio laser oltre i 40 W di potenza
# NaN    39
#  1     28
#  0      2
#  2      1
# dtype: int64
#
# Data %:
# NaN    55.714286
#  1     40.000000
#  0      2.857143
#  2      1.428571
# dtype: float64
#
# Data: statistics:
# count    31.000000
# mean      0.967742
# std       0.314523
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: D28[SQ006], dtype: float64
# Data:
#  Taglio vinile CNC
# NaN    39
#  1     26
#  0      4
#  2      1
# dtype: int64
#
# Data %:
# NaN    55.714286
#  1     37.142857
#  0      5.714286
#  2      1.428571
# dtype: float64
#
# Data: statistics:
# count    31.000000
# mean      0.903226
# std       0.396219
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: D28[SQ007], dtype: float64
# Data:
#  Taglio al plasma
# NaN    63
#  0      7
# dtype: int64
#
# Data %:
# NaN    90
#  0     10
# dtype: float64
#
# Data: statistics:
# count    7
# mean     0
# std      0
# min      0
# 25%      0
# 50%      0
# 75%      0
# max      0
# Name: D28[SQ008], dtype: float64
# Data:
#  Taglio a getto d’acqua
# NaN    62
#  0      7
#  1      1
# dtype: int64
#
# Data %:
# NaN    88.571429
#  0     10.000000
#  1      1.428571
# dtype: float64
#
# Data: statistics:
# count    8.000000
# mean     0.125000
# std      0.353553
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000
# Name: D28[SQ009], dtype: float64
# Data:
#  Stampanti 3D: tecnologia FDM
#  1     19
#  2     13
#  3     11
# NaN    10
#  4      9
#  6      3
#  7      2
#  5      2
#  10     1
# dtype: int64
#
# Data %:
#  1     27.142857
#  2     18.571429
#  3     15.714286
# NaN    14.285714
#  4     12.857143
#  6      4.285714
#  7      2.857143
#  5      2.857143
#  10     1.428571
# dtype: float64
#
# Data: statistics:
# count    60.000000
# mean      2.766667
# std       1.889908
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max      10.000000
# Name: D28[SQ010], dtype: float64
# Data:
#  Stampanti 3D: stereolitografia (SLA, DLP)
# NaN    55
#  1      9
#  0      5
#  2      1
# dtype: int64
#
# Data %:
# NaN    78.571429
#  1     12.857143
#  0      7.142857
#  2      1.428571
# dtype: float64
#
# Data: statistics:
# count    15.000000
# mean      0.733333
# std       0.593617
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: D28[SQ011], dtype: float64
# Data:
#  Stampanti 3D: a polvere
# NaN    60
#  0      7
#  1      3
# dtype: int64
#
# Data %:
# NaN    85.714286
#  0     10.000000
#  1      4.285714
# dtype: float64
#
# Data: statistics:
# count    10.000000
# mean      0.300000
# std       0.483046
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.750000
# max       1.000000
# Name: D28[SQ012], dtype: float64
# Data:
#  Micro-controller (Arduino, Raspberry PI,..)
# NaN     18
#  10     13
#  5      11
#  20      7
#  1       5
#  30      3
#  3       3
#  6       2
#  4       2
#  2       2
#  50      1
#  12      1
#  40      1
#  100     1
# dtype: int64
#
# Data %:
# NaN     25.714286
#  10     18.571429
#  5      15.714286
#  20     10.000000
#  1       7.142857
#  30      4.285714
#  3       4.285714
#  6       2.857143
#  4       2.857143
#  2       2.857143
#  50      1.428571
#  12      1.428571
#  40      1.428571
#  100     1.428571
# dtype: float64
#
# Data: statistics:
# count     52.000000
# mean      12.596154
# std       16.095621
# min        1.000000
# 25%        5.000000
# 50%       10.000000
# 75%       14.000000
# max      100.000000
# Name: D28[SQ013], dtype: float64
# Data:
#  Postazione di lavorazione elettronica (oscilloscopio, saldatore, ecc.)
#  1     31
# NaN    18
#  2      7
#  3      6
#  5      3
#  4      2
#  12     1
#  6      1
#  0      1
# dtype: int64
#
# Data %:
#  1     44.285714
# NaN    25.714286
#  2     10.000000
#  3      8.571429
#  5      4.285714
#  4      2.857143
#  12     1.428571
#  6      1.428571
#  0      1.428571
# dtype: float64
#
# Data: statistics:
# count    52.000000
# mean      2.000000
# std       1.940285
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.250000
# max      12.000000
# Name: D28[SQ016], dtype: float64
# Data:
#  Macchina da taglio e cucito digitale
# NaN    54
#  1     10
#  0      6
# dtype: int64
#
# Data %:
# NaN    77.142857
#  1     14.285714
#  0      8.571429
# dtype: float64
#
# Data: statistics:
# count    16.000
# mean      0.625
# std       0.500
# min       0.000
# 25%       0.000
# 50%       1.000
# 75%       1.000
# max       1.000
# Name: D28[SQ014], dtype: float64
# Data:
#  Macchina da ricamo digitale
# NaN    59
#  0      6
#  1      5
# dtype: int64
#
# Data %:
# NaN    84.285714
#  0      8.571429
#  1      7.142857
# dtype: float64
#
# Data: statistics:
# count    11.000000
# mean      0.454545
# std       0.522233
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
# Name: D28[SQ015], dtype: float64

# %%
# Plot the data 02

for k,i in enumerate(subquestions):
    
    space = data[i].value_counts(dropna=False)
    # Reorder value_counts by index natural order
    space1 = space.sort_index()

    plt.figure(figsize=(8,6))
    plt.title(u"Quali sono le dotazioni di macchinari di fabbricazione digitale del laboratorio? "+subquestions_value[k], fontsize=18)
    plt.xlabel(subquestions_value[k], fontsize=16)
    plt.ylabel('Lab', fontsize=16)

    # Plot the data
    my_colors = seaborn.color_palette("husl", len(space1)) # Set color palette
    space1.plot(kind='bar',color=my_colors)
    plt.savefig(u"svg/Q028-"+subquestions_value[k]+"02.svg")
    plt.savefig(u"png/Q028-"+subquestions_value[k]+"02.png")

# %%
for k,i in enumerate(subquestions):

    # Check histogram
    plt.figure(figsize=(8,6))
    plt.title(u"Quali sono le dotazioni di macchinari di fabbricazione digitale del laboratorio? "+subquestions_value[k], fontsize=18)
    plt.xlabel(subquestions_value[k], fontsize=16)
    plt.ylabel('Lab', fontsize=16)
    data[i].hist(bins=60)
    plt.savefig(u"svg/Q028-"+subquestions_value[k]+"03.svg")
    plt.savefig(u"png/Q028-"+subquestions_value[k]+"03.png")
