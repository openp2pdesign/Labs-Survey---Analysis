# %% [markdown]
# # Q030 - Quali altre dotazioni avete nel laboratorio?

# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %matplotlib inline 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import shutil

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier, overridden by seaborn
pd.set_option('display.max_columns', None) # Display all the columns
plt.rcParams['font.family'] = 'sans-serif' # Sans Serif fonts for all the graphs

# Reference for color palettes: http://web.stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html

# Change the font
matplotlib.rcParams.update({'font.family': 'Source Sans Pro'})

# %%
# Load csv file first
data = pd.read_csv("data/lab-survey.csv", encoding="utf-8")

# %%
# Check data
#data[0:4] # Equals to data.head()

# %%
# For each subquestion, plot the data
subquestions = ["D30[SQ002]","D30[SQ003]","D30[SQ004]","D30[SQ005]",
                "D30[SQ006]","D30[SQ007]","D30[SQ008]","D30[SQ009]",
                "D30[SQ010]","D30[SQ011]","D30[SQ012]","D30[SQ013]",
                "D30[SQ014]"]
subquestions_value = [u"Zona falegnameria",
                      u"Fusione di metalli", 
                      u"Lavorazioni ceramica", 
                      u"Lavorazioni vetro", 
                      u"Lavorazioni tessile", 
                      u"Fresatrice a controllo manuale", 
                      u"Tornio a controllo manuale", 
                      u"Trapano a colonna", 
                      u"Termoformatura", 
                      u"Produzione di circuiti per incisione", 
                      u"Macchina da taglio e cucito", 
                      u"Materiali per stampi in silicone e colatura resine", 
                      u"Attrezzature per Biolab"]

# %%
# %%capture output

# Save the output as a variable that can be saved to a file
for k,i in enumerate(subquestions):
    space = data[i].value_counts(dropna=False)
    print ""
    print "Data:",subquestions_value[k]
    print space
    print ""
    print "Data %:"
    print data[i].value_counts(normalize=True, dropna=False) * 100
    print ""
    print "Data: statistics:"
    print data[i].describe()

# %%
# Save+show the output to a text file
# %save Q030-Dotazioni.py str(output)
shutil.move("Q030-Dotazioni.py", "text/Q030-Dotazioni.txt")
# Out:
# The following commands were written to file `Q030-Dotazioni.py`:
#
# Data: Zona falegnameria
# NaN    34
#  1     32
#  4      1
#  3      1
#  2      1
# dtype: int64
#
# Data %:
# NaN    49.275362
#  1     46.376812
#  4      1.449275
#  3      1.449275
#  2      1.449275
# dtype: float64
#
# Data: statistics:
# count    35.000000
# mean      1.171429
# std       0.617667
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       4.000000
# Name: D30[SQ002], dtype: float64
#
# Data: Fusione di metalli
# NaN    64
#  0      3
#  2      1
#  1      1
# dtype: int64
#
# Data %:
# NaN    92.753623
#  0      4.347826
#  2      1.449275
#  1      1.449275
# dtype: float64
#
# Data: statistics:
# count    5.000000
# mean     0.600000
# std      0.894427
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      2.000000
# Name: D30[SQ003], dtype: float64
#
# Data: Lavorazioni ceramica
# NaN    61
#  1      5
#  0      3
# dtype: int64
#
# Data %:
# NaN    88.405797
#  1      7.246377
#  0      4.347826
# dtype: float64
#
# Data: statistics:
# count    8.000000
# mean     0.625000
# std      0.517549
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000
# Name: D30[SQ004], dtype: float64
#
# Data: Lavorazioni vetro
# NaN    64
#  0      3
#  1      2
# dtype: int64
#
# Data %:
# NaN    92.753623
#  0      4.347826
#  1      2.898551
# dtype: float64
#
# Data: statistics:
# count    5.000000
# mean     0.400000
# std      0.547723
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000
# Name: D30[SQ005], dtype: float64
#
# Data: Lavorazioni tessile
# NaN    52
#  1     14
#  0      2
#  2      1
# dtype: int64
#
# Data %:
# NaN    75.362319
#  1     20.289855
#  0      2.898551
#  2      1.449275
# dtype: float64
#
# Data: statistics:
# count    17.000000
# mean      0.941176
# std       0.428746
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: D30[SQ006], dtype: float64
#
# Data: Fresatrice a controllo manuale
# NaN    54
#  1     12
#  0      3
# dtype: int64
#
# Data %:
# NaN    78.260870
#  1     17.391304
#  0      4.347826
# dtype: float64
#
# Data: statistics:
# count    15.000000
# mean      0.800000
# std       0.414039
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: D30[SQ007], dtype: float64
#
# Data: Tornio a controllo manuale
# NaN    57
#  1      7
#  0      3
#  3      1
#  2      1
# dtype: int64
#
# Data %:
# NaN    82.608696
#  1     10.144928
#  0      4.347826
#  3      1.449275
#  2      1.449275
# dtype: float64
#
# Data: statistics:
# count    12.000000
# mean      1.000000
# std       0.852803
# min       0.000000
# 25%       0.750000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: D30[SQ008], dtype: float64
#
# Data: Trapano a colonna
#  1     33
# NaN    32
#  2      4
# dtype: int64
#
# Data %:
#  1     47.826087
# NaN    46.376812
#  2      5.797101
# dtype: float64
#
# Data: statistics:
# count    37.000000
# mean      1.108108
# std       0.314800
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: D30[SQ009], dtype: float64
#
# Data: Termoformatura
# NaN    56
#  1     10
#  0      3
# dtype: int64
#
# Data %:
# NaN    81.159420
#  1     14.492754
#  0      4.347826
# dtype: float64
#
# Data: statistics:
# count    13.000000
# mean      0.769231
# std       0.438529
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: D30[SQ010], dtype: float64
#
# Data: Produzione di circuiti per incisione
# NaN    49
#  1     16
#  0      3
#  3      1
# dtype: int64
#
# Data %:
# NaN    71.014493
#  1     23.188406
#  0      4.347826
#  3      1.449275
# dtype: float64
#
# Data: statistics:
# count    20.000000
# mean      0.950000
# std       0.604805
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: D30[SQ011], dtype: float64
#
# Data: Macchina da taglio e cucito
# NaN    42
#  1     24
#  0      1
#  2      1
#  8      1
# dtype: int64
#
# Data %:
# NaN    60.869565
#  1     34.782609
#  0      1.449275
#  2      1.449275
#  8      1.449275
# dtype: float64
#
# Data: statistics:
# count    27.000000
# mean      1.259259
# std       1.375405
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       8.000000
# Name: D30[SQ012], dtype: float64
#
# Data: Materiali per stampi in silicone e colatura resine
# NaN    54
#  1     12
#  0      3
# dtype: int64
#
# Data %:
# NaN    78.260870
#  1     17.391304
#  0      4.347826
# dtype: float64
#
# Data: statistics:
# count    15.000000
# mean      0.800000
# std       0.414039
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: D30[SQ013], dtype: float64
#
# Data: Attrezzature per Biolab
# NaN    65
#  0      3
#  20     1
# dtype: int64
#
# Data %:
# NaN    94.202899
#  0      4.347826
#  20     1.449275
# dtype: float64
#
# Data: statistics:
# count     4
# mean      5
# std      10
# min       0
# 25%       0
# 50%       0
# 75%       5
# max      20
# Name: D30[SQ014], dtype: float64

# %%
for k,i in enumerate(subquestions):
    # Plot the data 01
    plt.figure(figsize=(8,6))
    plt.xlabel(subquestions_value[k], fontsize=16)
    plt.ylabel('Lab', fontsize=16)
    plt.title(u"Quali altre dotazioni avete nel laboratorio? "+subquestions_value[k], fontsize=18, y=1.02)
    my_colors = seaborn.color_palette("husl", len(space)) # Set color palette
    space.plot(kind="bar",color=my_colors)
    plt.savefig(u"svg/Q030-"+subquestions_value[k]+"01.svg")
    plt.savefig(u"png/Q030-"+subquestions_value[k]+"01.png")
    plt.savefig(u"pdf/Q030-"+subquestions_value[k]+"01.pdf")

# %%
# Plot the data 02

for k,i in enumerate(subquestions):
    
    space = data[i].value_counts(dropna=False)
    # Reorder value_counts by index natural order
    space1 = space.sort_index()

    plt.figure(figsize=(8,6))
    plt.title(u"Quali altre dotazioni avete nel laboratorio? "+subquestions_value[k], fontsize=18, y=1.02)
    plt.xlabel(subquestions_value[k], fontsize=16)
    plt.ylabel('Lab', fontsize=16)

    # Plot the data
    my_colors = seaborn.color_palette("husl", len(space1)) # Set color palette
    space1.plot(kind='bar',color=my_colors)
    plt.savefig(u"svg/Q030-"+subquestions_value[k]+"02.svg")
    plt.savefig(u"png/Q030-"+subquestions_value[k]+"02.png")
    plt.savefig(u"pdf/Q030-"+subquestions_value[k]+"02.pdf")

# %%
for k,i in enumerate(subquestions):

    # Check histogram
    plt.figure(figsize=(8,6))
    plt.title(u"Quali altre dotazioni avete nel laboratorio? "+subquestions_value[k], fontsize=18, y=1.02)
    plt.xlabel(subquestions_value[k], fontsize=16)
    plt.ylabel('Lab', fontsize=16)
    data[i].hist(bins=60)
    plt.savefig(u"svg/Q030-"+subquestions_value[k]+"03.svg")
    plt.savefig(u"png/Q030-"+subquestions_value[k]+"03.png")
    plt.savefig(u"pdf/Q030-"+subquestions_value[k]+"03.pdf")
